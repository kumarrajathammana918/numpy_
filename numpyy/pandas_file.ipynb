# %%
print(a)
# Out:
# [[12 25 95 24 77]
#  [58 54 65 34 24]
#  [44 45 33 66 56]]

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\DELL\\Downloads\\Superstore sales dataset.csv")

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.head
# Out:
# <bound method NDFrame.head of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   12/6/2016   16/6/2016    Second Class
# 3          4  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# 4          5  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   21/1/2014   23/1/2014    Second Class
# 9990    9991  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    4/5/2017    9/5/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   12/6/2016   16/6/2016    Second Class
# 3          4  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# 4          5  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   21/1/2014   23/1/2014    Second Class
# 9990    9991  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    4/5/2017    9/5/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.index

df.columns

df.head(4)

df.tail
# Out:
# <bound method NDFrame.tail of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   12/6/2016   16/6/2016    Second Class
# 3          4  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# 4          5  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   21/1/2014   23/1/2014    Second Class
# 9990    9991  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    4/5/2017    9/5/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.max()
# Out:
# Row ID                                         9994
# Order ID                             US-2017-169551
# Order Date                                 9/9/2017
# Ship Date                                  9/9/2017
# Ship Mode                            Standard Class
# Customer ID                                ZD-21925
# Customer Name                    Zuschuss Donatelli
# Segment                                 Home Office
# Country                               United States
# City                                           Yuma
# State                                       Wyoming
# Postal Code                                   99301
# Region                                         West
# Product ID                          TEC-PH-10004977
# Category                                 Technology
# Sub-Category                                 Tables
# Product Name     netTALK DUO VoIP Telephone Service
# Sales                                      22638.48
# ...

# %%
df.min()
# Out:
# Row ID                                                           1
# Order ID                                            CA-2014-100006
# Order Date                                                1/1/2017
# Ship Date                                                 1/1/2015
# Ship Mode                                              First Class
# Customer ID                                               AA-10315
# Customer Name                                        Aaron Bergman
# Segment                                                   Consumer
# Country                                              United States
# City                                                      Aberdeen
# State                                                      Alabama
# Postal Code                                                   1040
# Region                                                     Central
# Product ID                                         FUR-BO-10000112
# ...

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df[['Profit','Discount','Sales']].mean()
# Out:
# Profit       28.656896
# Discount      0.156203
# Sales       229.858001
# dtype: float64

# %%
df['Quantity'].sum()
# Out:
# np.int64(37873)

# %%
df.select_dtypes(include=['float'])
# Out:
#          Sales  Discount    Profit
# 0     261.9600      0.00   41.9136
# 1     731.9400      0.00  219.5820
# 2      14.6200      0.00    6.8714
# 3     957.5775      0.45 -383.0310
# 4      22.3680      0.20    2.5164
# ...        ...       ...       ...
# 9989   25.2480      0.20    4.1028
# 9990   91.9600      0.00   15.6332
# 9991  258.5760      0.20   19.3932
# 9992   29.6000      0.00   13.3200
# 9993  243.1600      0.00   72.9480
#
# [9994 rows x 3 columns]

# %%
df.select_dtypes(include=['int']).shape
# Out:
# (9994, 3)

# %%
df['Customer Name'].str.lower()                     # 1. Lowercase
df['Customer Name'].str.upper()                     # 2. Uppercase
df['Customer Name'].str.len()                       # 3. Length
df['Customer Name'].str.strip()                     # 4. Remove spaces
df['City'].str.replace("New York", "NY")            # 5. Replace text
df[df['Product Name'].str.contains("Chair")]        # 6. Contains
df[df['Customer Name'].str.startswith("A")]         # 7. Startswith
df[df['Customer Name'].str.endswith("n")]           # 8. Endswith
df['First Name'] = df['Customer Name'].str.split().str[0]  # 9. Split
df['Order Number'] = df['Order ID'].str.extract('(\d+)')   # 10. Extract numbers

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df['Country'].str.lower()
# Out:
# 0       united states
# 1       united states
# 2       united states
# 3       united states
# 4       united states
#             ...
# 9989    united states
# 9990    united states
# 9991    united states
# 9992    united states
# 9993    united states
# Name: Country, Length: 9994, dtype: str

# %%
df['City'].str.upper()
# Out:
# 0             HENDERSON
# 1             HENDERSON
# 2           LOS ANGELES
# 3       FORT LAUDERDALE
# 4       FORT LAUDERDALE
#              ...
# 9989              MIAMI
# 9990         COSTA MESA
# 9991         COSTA MESA
# 9992         COSTA MESA
# 9993        WESTMINSTER
# Name: City, Length: 9994, dtype: str

# %%
df['Product Name'].str.len()
# Out:
# 0       33
# 1       59
# 2       57
# 3       45
# 4       30
#         ..
# 9989    22
# 9990    50
# 9991    21
# 9992    49
# 9993    73
# Name: Product Name, Length: 9994, dtype: int64

# %%
df['Country'].str.replace('United States','vizag')
# Out:
# 0       vizag
# 1       vizag
# 2       vizag
# 3       vizag
# 4       vizag
#         ...
# 9989    vizag
# 9990    vizag
# 9991    vizag
# 9992    vizag
# 9993    vizag
# Name: Country, Length: 9994, dtype: str

# %%
df[df['Category'].str.contains('Furniture')]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 3          4  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# 5          6  CA-2014-115812    9/6/2014   14/6/2014  Standard Class
# 10        11  CA-2014-115812    9/6/2014   14/6/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9962    9963  CA-2015-168088   19/3/2015   22/3/2015     First Class
# 9964    9965  CA-2016-146374   5/12/2016  10/12/2016    Second Class
# 9980    9981  US-2015-151435    6/9/2015    9/9/2015    Second Class
# 9989    9990  CA-2014-110422   21/1/2014   23/1/2014    Second Class
# 9990    9991  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 0       CG-12520       Claire Gute     Consumer  United States
# ...

# %%
df[df['Region'].str.startswith("W")]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2          3  CA-2016-138688  12/6/2016  16/6/2016    Second Class
# 5          6  CA-2014-115812   9/6/2014  14/6/2014  Standard Class
# 6          7  CA-2014-115812   9/6/2014  14/6/2014  Standard Class
# 7          8  CA-2014-115812   9/6/2014  14/6/2014  Standard Class
# 8          9  CA-2014-115812   9/6/2014  14/6/2014  Standard Class
# ...      ...             ...        ...        ...             ...
# 9986    9987  CA-2016-125794  29/9/2016  3/10/2016  Standard Class
# 9990    9991  CA-2017-121258  26/2/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  26/2/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  26/2/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   4/5/2017   9/5/2017    Second Class
#
#      Customer ID    Customer Name    Segment        Country         City  ...  \
# 2       DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles  ...
# ...

# %%
df[df['Customer Name'].str.endswith("A")]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 912      913  CA-2015-133627   31/5/2015    7/6/2015  Standard Class
# 2004    2005  US-2017-143028   11/4/2017   18/4/2017  Standard Class
# 3661    3662  CA-2016-155005   13/6/2016   15/6/2016    Second Class
# 4840    4841  CA-2017-154123  20/11/2017  25/11/2017  Standard Class
# 4998    4999  CA-2016-129238   31/1/2016    4/2/2016  Standard Class
# 4999    5000  CA-2016-129238   31/1/2016    4/2/2016  Standard Class
# 5635    5636  CA-2017-123022    3/9/2017    8/9/2017  Standard Class
# 5636    5637  CA-2017-123022    3/9/2017    8/9/2017  Standard Class
# 7327    7328  US-2014-131275   18/3/2014   24/3/2014  Standard Class
# 7328    7329  US-2014-131275   18/3/2014   24/3/2014  Standard Class
# 7329    7330  US-2014-131275   18/3/2014   24/3/2014  Standard Class
# 9687    9688  US-2017-130603   30/9/2017   6/10/2017  Standard Class
# 9769    9770  CA-2016-123533  24/11/2016  30/11/2016  Standard Class
# ...

# %%
df['First Name'] = df['Customer Name'].str.split().str[0]

# %%
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   12/6/2016   16/6/2016    Second Class
# 3          4  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# 4          5  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   21/1/2014   23/1/2014    Second Class
# 9990    9991  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    4/5/2017    9/5/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df['Sales'].plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df['Sales'].plot()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\plotting\_core.py:2253, in _get_plot_backend(backend)
#    2250 if backend_str in _backends:
#    2251     return _backends[backend_str]
# -> 2253 module = _load_backend(backend_str)
#    2254 _backends[backend_str] = module
# ...

# %% [markdown]
# # 1️⃣ Line Plot
# df['Sales'].plot(title="Line Plot - Sales Trend")
#
# # 2️⃣ Multiple Line Plot
# df[['Sales','Profit']].plot(title="Multiple Line Plot")
#
# # 3️⃣ Bar Plot
# df['Sales'].plot(kind='bar', title="Bar Plot - Sales")
#
# # 4️⃣ Stacked Bar Plot
# df[['Sales','Profit']].plot(kind='bar', stacked=True, title="Stacked Bar Plot")
#
# # 5️⃣ Horizontal Bar Plot
# df['Sales'].plot(kind='barh', title="Horizontal Bar Plot")
#
# # 6️⃣ Histogram
# df['Sales'].plot(kind='hist', bins=5, title="Histogram - Sales")
#
# # 7️⃣ Box Plot
# df[['Sales','Profit']].plot(kind='box', title="Box Plot")
#
# # 8️⃣ Area Plot
# df[['Sales','Profit']].plot(kind='area', title="Area Plot")
#
# # 9️⃣ Pie Chart
# df['Sales'].plot(kind='pie', autopct='%1.1f%%', title="Pie Chart - Sales")
#
# # 🔟 Scatter Plot
# df.plot(kind='scatter', x='Sales', y='Profit', title="Scatter Plot")
# sbp-sxnv-zfu

# %%
import pandas as pd
import numpy as np
df['Sales'].plot()
# Out:
# <Axes: >

# %%
df[['Sales','Discount']].plot(title="Multiple Line Plot")
# Out:
# <Axes: title={'center': 'Multiple Line Plot'}>

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   8/11/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   12/6/2016   16/6/2016    Second Class
# 3          4  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# 4          5  US-2015-108966  11/10/2015  18/10/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   21/1/2014   23/1/2014    Second Class
# 9990    9991  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   26/2/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    4/5/2017    9/5/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...
